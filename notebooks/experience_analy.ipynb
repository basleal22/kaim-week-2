# %%
import os
print(os.getcwd())
os.chdir('c:/Users/hp/Desktop/tutorial/kaim-week-2/')
# Out:
# c:\Users\hp\Desktop\tutorial\kaim-week-2\notebooks

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
path_2 = 'C:/Users/hp/Desktop/tutorial/kaim-week-2/data/cleaned_data.csv'
data=pd.read_csv(path_2)
#data_2=pd.read_excel(path_2)
data.columns
#data.isnull().sum()
# Out:
# Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'Activity Duration DL (ms)', 'Activity Duration UL (ms)', 'Dur. (ms).1',
#        'Handset Manufacturer', 'Handset Type', 'Nb of sec with Vol DL < 6250B',
#        'Nb of sec with Vol UL < 1250B', 'Social Media DL (Bytes)',
#        'Social Media UL (Bytes)', 'Google DL (Bytes)', 'Google UL (Bytes)',
#        'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)',
#        'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)',
# ...

# %%
from scripts.aggregate import aggregated
aggregated_data=aggregated(data)
aggregated_data.head()
# Out:
#    MSISDN/Number  Avg RTT DL (ms)  Avg RTT UL (ms)  Avg Bearer TP DL (kbps)  \
# 0   3.360100e+10        46.000000         0.000000                     37.0
# 1   3.360100e+10        30.000000         1.000000                     48.0
# 2   3.360100e+10       109.795706        17.662883                     48.0
# 3   3.360101e+10        69.000000        15.000000                    204.0
# 4   3.360101e+10        57.000000         2.500000                  20197.5
#
#    Avg Bearer TP UL (kbps)                    Handset Type
# 0                     39.0  Huawei P20 Lite Huawei Nova 3E
# 1                     51.0          Apple iPhone 7 (A1778)
# 2                     49.0                       undefined
# 3                     44.0         Apple iPhone 5S (A1457)
# 4                   8224.5         Apple iPhone Se (A1723)

# %%
from scripts.aggregate import top_10_values
top_10,bottom_10,most_frequent=top_10_values(data)
top_10=pd.DataFrame(top_10)
bottom_10=pd.DataFrame(bottom_10)
most_frequent=pd.DataFrame(most_frequent)
print('top 10 values',pd.DataFrame(top_10))
print('bottom_10',bottom_10)
print('most frequent',most_frequent)
# Out:
# top 10 values                                                                        RTT  \
# Avg RTT DL (ms)          [96923.0, 64640.0, 55811.0, 54847.0, 26971.0, ...
# Avg RTT UL (ms)          [7120.0, 5607.0, 5422.0, 5279.0, 4677.0, 4226....
# Avg Bearer TP DL (kbps)                                                NaN
# Avg Bearer TP UL (kbps)                                                NaN
#
#                                                                 Throughput
# Avg RTT DL (ms)                                                        NaN
# Avg RTT UL (ms)                                                        NaN
# Avg Bearer TP DL (kbps)  [378160.0, 299257.0, 299002.0, 276040.0, 26936...
# Avg Bearer TP UL (kbps)  [58613.0, 57792.0, 57750.0, 57006.0, 56763.0, ...
# bottom_10                                                                        RTT  \
# Avg RTT DL (ms)          [0.0, 0.0, 0.0, 4.0, 5.0, 6.0, 7.0, 8.0, 8.0, ...
# ...

# %%
from scripts.aggregate import distribution_visualize
visualized_data = distribution_visualize(data)
visualized_data
# Out:
# [autoreload of scripts.aggregate failed: Traceback (most recent call last):
#   File "c:\Users\hp\Desktop\tutorial\kaim-week-2\venv\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\Desktop\tutorial\kaim-week-2\venv\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "C:\Program Files\Python313\Lib\importlib\__init__.py", line 129, in reload
#     _bootstrap._exec(spec, module)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 1018, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1156, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1086, in source_to_code
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ...

# %%
from scripts.aggregate import performance_clusters
cluster_summary=performance_clusters(data)
print(cluster_summary)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from scripts.aggregate import performance_clusters
#       2 cluster_summary=performance_clusters(data)
#       3 print(cluster_summary)
#
# ImportError: cannot import name 'performance_clusters' from 'scripts.aggregate' (c:\Users\hp\Desktop\tutorial\kaim-week-2\scripts\aggregate.py)
